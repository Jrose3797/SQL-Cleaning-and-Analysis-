# %%
import pandas as pd
import sqlite3
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
conn = sqlite3.connect('data.sqlite')
c = conn.cursor()

# %%
import pandas as pd
c.execute("""SELECT * FROM employees""")
df = pd.DataFrame(c.fetchall())
df.head()
# Out:
#       0          1        2      3                                4  5     6  \
# 0  1002     Murphy    Diane  x5800     dmurphy@classicmodelcars.com  1
# 1  1056  Patterson     Mary  x4611   mpatterso@classicmodelcars.com  1  1002
# 2  1076   Firrelli     Jeff  x9273   jfirrelli@classicmodelcars.com  1  1002
# 3  1088  Patterson  William  x4871  wpatterson@classicmodelcars.com  6  1056
# 4  1102     Bondur   Gerard  x5408     gbondur@classicmodelcars.com  4  1056
#
#                       7
# 0             President
# 1              VP Sales
# 2          VP Marketing
# 3  Sales Manager (APAC)
# 4   Sale Manager (EMEA)

# %% [markdown]
# Selected customers from a certain city.

# %%
c.execute("""SELECT * FROM customers WHERE city = 'Boston';""")
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#   customerNumber          customerName contactLastName contactFirstName  \
# 0            362     Gifts4AllAges.com         Yoshido             Juri
# 1            495  Diecast Collectables          Franco          Valarie
#
#         phone        addressLine1 addressLine2    city state postalCode  \
# 0  6175559555  8616 Spinnaker Dr.               Boston    MA      51003
# 1  6175552555      6251 Ingle Ln.               Boston    MA      51003
#
#   country salesRepEmployeeNumber creditLimit
# 0     USA                   1216    41900.00
# 1     USA                   1188    85100.00

# %% [markdown]
# Selected customers from multiple cities.

# %%
c.execute("""SELECT * FROM customers WHERE city = 'Boston' OR city = 'Madrid';""")
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#   customerNumber                customerName contactLastName contactFirstName  \
# 0            141      Euro+ Shopping Channel          Freyre           Diego
# 1            237               ANG Resellers          Camino       Alejandra
# 2            344                 CAF Imports       Fernandez            Jesus
# 3            362           Gifts4AllAges.com         Yoshido             Juri
# 4            458  Corrida Auto Replicas, Ltd          Sommer          Martín
# 5            465         Anton Designs, Ltd.           Anton           Carmen
# 6            495        Diecast Collectables          Franco          Valarie
#
#              phone                      addressLine1           addressLine2  \
# 0   (91) 555 94 44                C/ Moralzarzal, 86
# 1    (91) 745 6555                       Gran Vía, 1
# 2  +34 913 728 555                   Merchants House  27-30 Merchant's Quay
# 3       6175559555                8616 Spinnaker Dr.
# ...

# %% [markdown]
# Added a conditional for customer credit limit and limited the amount of results.

# %%
c.execute("""SELECT *
             FROM customers
             WHERE (city = 'Boston' or city = 'Madrid')
                   AND (creditLimit >= 50000.00)
             LIMIT 15
             ;""")
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df.head()
# Out:
#   customerNumber                customerName contactLastName contactFirstName  \
# 0            141      Euro+ Shopping Channel          Freyre           Diego
# 1            237               ANG Resellers          Camino       Alejandra
# 2            344                 CAF Imports       Fernandez            Jesus
# 3            362           Gifts4AllAges.com         Yoshido             Juri
# 4            458  Corrida Auto Replicas, Ltd          Sommer          Martín
#
#              phone        addressLine1           addressLine2    city state  \
# 0   (91) 555 94 44  C/ Moralzarzal, 86                         Madrid
# 1    (91) 745 6555         Gran Vía, 1                         Madrid
# 2  +34 913 728 555     Merchants House  27-30 Merchant's Quay  Madrid
# 3       6175559555  8616 Spinnaker Dr.                         Boston    MA
# 4   (91) 555 22 82      C/ Araquil, 67                         Madrid
#
#   postalCode country salesRepEmployeeNumber creditLimit
# ...

# %% [markdown]
# Selected customers and ordered by Customer name.

# %%
c.execute("""SELECT *
             FROM customers
             ORDER BY customerName
             ;""")
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df.head()
# Out:
#   customerNumber            customerName contactLastName contactFirstName  \
# 0            237           ANG Resellers          Camino       Alejandra
# 1            187          AV Stores, Co.        Ashworth           Rachel
# 2            242            Alpha Cognac          Roulet         Annette
# 3            168  American Souvenirs Inc          Franco            Keith
# 4            249      Amica Models & Co.         Accorti           Paolo
#
#             phone           addressLine1 addressLine2        city state  \
# 0   (91) 745 6555            Gran Vía, 1                   Madrid
# 1  (171) 555-1555      Fauntleroy Circus               Manchester
# 2      61.77.6555  1 rue Alsace-Lorraine                 Toulouse
# 3      2035557845      149 Spinnaker Dr.    Suite 101   New Haven    CT
# 4     011-4988555    Via Monte Bianco 34                   Torino
#
#   postalCode country salesRepEmployeeNumber creditLimit
# 0      28001   Spain                               0.00
# ...

# %% [markdown]
# Joining two tables on officecode column, isolated Bostom employees.

# %%
c.execute("""SELECT * FROM employees
                        JOIN offices
                        ON employees.officeCode = offices.officeCode
                        WHERE city == 'Boston';
                       """)
df = pd.DataFrame(c.fetchall()) 
df.columns = [i[0] for i in c.description]
df.head()
# Out:
#   employeeNumber   lastName firstName extension  \
# 0           1188   Firrelli     Julie     x2173
# 1           1216  Patterson     Steve     x4334
#
#                              email officeCode reportsTo   jobTitle officeCode  \
# 0   jfirrelli@classicmodelcars.com          2      1143  Sales Rep          2
# 1  spatterson@classicmodelcars.com          2      1143  Sales Rep          2
#
#      city            phone      addressLine1 addressLine2 state country  \
# 0  Boston  +1 215 837 0825  1550 Court Place    Suite 102    MA     USA
# 1  Boston  +1 215 837 0825  1550 Court Place    Suite 102    MA     USA
#
#   postalCode territory
# 0      02107        NA
# 1      02107        NA

# %%
c.execute("""SELECT * FROM products
                        LEFT JOIN orderdetails
                        USING(productCode);
                       """)
df = pd.DataFrame(c.fetchall()) 
df.columns = [i[0] for i in c.description]
print(len(df))
df.head()
# Out:
# 2997
#   productCode                            productName  productLine  \
# 0    S10_1678  1969 Harley Davidson Ultimate Chopper  Motorcycles
# 1    S10_1678  1969 Harley Davidson Ultimate Chopper  Motorcycles
# 2    S10_1678  1969 Harley Davidson Ultimate Chopper  Motorcycles
# 3    S10_1678  1969 Harley Davidson Ultimate Chopper  Motorcycles
# 4    S10_1678  1969 Harley Davidson Ultimate Chopper  Motorcycles
#
#   productScale    productVendor  \
# 0         1:10  Min Lin Diecast
# 1         1:10  Min Lin Diecast
# 2         1:10  Min Lin Diecast
# 3         1:10  Min Lin Diecast
# 4         1:10  Min Lin Diecast
#
#                                   productDescription quantityInStock buyPrice  \
# 0  This replica features working kickstand, front...            7933    48.81
# 1  This replica features working kickstand, front...            7933    48.81
# 2  This replica features working kickstand, front...            7933    48.81
# ...

# %% [markdown]
# Locating what city has the most employees per office, and put them in descending order.

# %%
c.execute("""SELECT city,
                      COUNT(employeeNumber) AS numEmployees
                      FROM offices
                      JOIN employees
                      USING(officeCode)
                      GROUP BY city
                      ORDER BY numEmployees desc;""")
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df.head()
# Out:
#             city  numEmployees
# 0  San Francisco             6
# 1          Paris             5
# 2         Sydney             4
# 3         Boston             2
# 4         London             2

# %%
c.execute("""SELECT * FROM products
                        LEFT JOIN orderdetails
                        USING(productCode);
                       """)
df = pd.DataFrame(c.fetchall()) 
df.columns = [i[0] for i in c.description]
print(len(df))
df.head()
# Out:
# 2997
#   productCode                            productName  productLine  \
# 0    S10_1678  1969 Harley Davidson Ultimate Chopper  Motorcycles
# 1    S10_1678  1969 Harley Davidson Ultimate Chopper  Motorcycles
# 2    S10_1678  1969 Harley Davidson Ultimate Chopper  Motorcycles
# 3    S10_1678  1969 Harley Davidson Ultimate Chopper  Motorcycles
# 4    S10_1678  1969 Harley Davidson Ultimate Chopper  Motorcycles
#
#   productScale    productVendor  \
# 0         1:10  Min Lin Diecast
# 1         1:10  Min Lin Diecast
# 2         1:10  Min Lin Diecast
# 3         1:10  Min Lin Diecast
# 4         1:10  Min Lin Diecast
#
#                                   productDescription quantityInStock buyPrice  \
# 0  This replica features working kickstand, front...            7933    48.81
# 1  This replica features working kickstand, front...            7933    48.81
# 2  This replica features working kickstand, front...            7933    48.81
# ...

# %% [markdown]
# Created an empty list to append employees whose stock ownership is within 500-10000 shares.

# %%
l=[]
for i in df.quantityInStock:
   i=int(i)
   l.append(i)
df.quantityInStock=l
df.query('10000>quantityInStock >500').head()
# Out:
#   productCode                            productName  productLine  \
# 0    S10_1678  1969 Harley Davidson Ultimate Chopper  Motorcycles
# 1    S10_1678  1969 Harley Davidson Ultimate Chopper  Motorcycles
# 2    S10_1678  1969 Harley Davidson Ultimate Chopper  Motorcycles
# 3    S10_1678  1969 Harley Davidson Ultimate Chopper  Motorcycles
# 4    S10_1678  1969 Harley Davidson Ultimate Chopper  Motorcycles
#
#   productScale    productVendor  \
# 0         1:10  Min Lin Diecast
# 1         1:10  Min Lin Diecast
# 2         1:10  Min Lin Diecast
# 3         1:10  Min Lin Diecast
# 4         1:10  Min Lin Diecast
#
#                                   productDescription  quantityInStock  \
# 0  This replica features working kickstand, front...             7933
# 1  This replica features working kickstand, front...             7933
# 2  This replica features working kickstand, front...             7933
# 3  This replica features working kickstand, front...             7933
# ...
